# %% [markdown]
# <a href="https://colab.research.google.com/github/keertivardhan747/OpenCV/blob/main/Football_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
fifa = pd.read_csv('/content/FIFA_Processed_Data.csv', encoding='latin1')

# %%
fifa.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0      ID               Name  Age  \
# 0             0           0  158023           L. Messi   31
# 1             1           1   20801  Cristiano Ronaldo   33
# 2             2           2  190871          Neymar Jr   26
# 3             3           3  193080             De Gea   27
# 4             4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  ... Composure  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94  ...      96.0
# 1  https://cdn.sofifa.org/flags/38.png       94         94  ...      95.0
# ...

# %%
for col in fifa.columns:
  print(col)
# Out:
# Unnamed: 0.1
# Unnamed: 0
# ID
# Name
# Age
# Photo
# Nationality
# Flag
# Overall
# Potential
# Club
# Club Logo
# Value
# Wage
# Special
# Preferred Foot
# International Reputation
# Weak Foot
# Skill Moves
# Work Rate
# Body Type
# Real Face
# Position
# Jersey Number
# Joined
# Loaned From
# Contract Valid Until
# Height
# Weight
# LS
# ST
# RS
# LW
# LF
# CF
# RF
# RW
# LAM
# CAM
# RAM
# LM
# LCM
# CM
# RCM
# RM
# LWB
# LDM
# CDM
# RDM
# RWB
# LB
# LCB
# CB
# RCB
# RB
# Crossing
# Finishing
# HeadingAccuracy
# ShortPassing
# Volleys
# Dribbling
# Curve
# FKAccuracy
# LongPassing
# BallControl
# Acceleration
# SprintSpeed
# Agility
# Reactions
# Balance
# ShotPower
# Jumping
# Stamina
# Strength
# LongShots
# Aggression
# Interceptions
# Positioning
# Vision
# Penalties
# Composure
# Marking
# StandingTackle
# SlidingTackle
# GKDiving
# GKHandling
# GKKicking
# GKPositioning
# GKReflexes
# Release Clause

# %%
fifa.shape
# Out:
# (18207, 90)

# %%
fifa['Nationality'].value_counts()
# Out:
# Nationality
# England        1662
# Germany        1198
# Spain          1072
# Argentina       937
# France          914
#                ...
# Malta             1
# Belize            1
# South Sudan       1
# Indonesia         1
# Botswana          1
# Name: count, Length: 164, dtype: int64

# %%
fifa['Nationality'].value_counts()[0:10]
# Out:
# Nationality
# England        1662
# Germany        1198
# Spain          1072
# Argentina       937
# France          914
# Brazil          827
# Italy           702
# Colombia        618
# Japan           478
# Netherlands     453
# Name: count, dtype: int64

# %%
fifa['Nationality'].value_counts()[0:5]
# Out:
# Nationality
# England      1662
# Germany      1198
# Spain        1072
# Argentina     937
# France        914
# Name: count, dtype: int64

# %%
fifa['Nationality'].value_counts()[0:5].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'Argentina', 'France'], dtype='object', name='Nationality')

# %%
plt.figure(figsize=(8,3))
plt.bar(fifa['Nationality'].value_counts()[0:5].keys(), fifa['Nationality'].value_counts()[0:5], color="g")
plt.show()

# %%
player_salary = fifa[['Name','Wage']]

# %%
player_salary.head()
# Out:
#                 Name    Wage
# 0           L. Messi  565000
# 1  Cristiano Ronaldo  405000
# 2          Neymar Jr  290000
# 3             De Gea  260000
# 4       K. De Bruyne  355000

# %%
player_salary=player_salary.sort_values(by=['Wage'],ascending=False)
player_salary.head()
# Out:
#                 Name    Wage
# 0           L. Messi  565000
# 7         L. SuÃ¡rez  455000
# 6         L. ModriÄ  420000
# 1  Cristiano Ronaldo  405000
# 8       Sergio Ramos  380000

# %%
plt.figure(figsize=(8,3))
plt.bar(list(player_salary['Name'])[0:5], list(player_salary['Wage'])[0:5], color="g")
plt.show()

# %%
fifa['Nationality']=='Germany'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18202    False
# 18203    False
# 18204    False
# 18205    False
# 18206    False
# Name: Nationality, Length: 18207, dtype: bool

# %%
Germany=fifa[fifa['Nationality']=='Germany']
Germany.head(10)
# Out:
#     Unnamed: 0.1  Unnamed: 0      ID           Name  Age  \
# 11            11          11  182521       T. Kroos   28
# 18            18          18  192448  M. ter Stegen   26
# 22            22          22  167495       M. Neuer   32
# 34            34          34  178603     M. Hummels   29
# 55            55          55  222492       L. SanÃ©   22
# 66            66          66  189596     T. MÃ¼ller   28
# 68            68          68  188350        M. Reus   29
# 74            74          74  176635       M. Ãzil   29
# 82            82          82  212622     J. Kimmich   23
# 95            95          95  183907     J. Boateng   29
#
#                                              Photo Nationality  \
# 11  https://cdn.sofifa.org/players/4/19/182521.png     Germany
# 18  https://cdn.sofifa.org/players/4/19/192448.png     Germany
# 22  https://cdn.sofifa.org/players/4/19/167495.png     Germany
# 34  https://cdn.sofifa.org/players/4/19/178603.png     Germany
# ...

# %%
Germany.sort_values(by=['Height'],ascending=False).head()
# Out:
#        Unnamed: 0.1  Unnamed: 0      ID            Name  Age  \
# 1225           1225        1225  200212        M. Esser   30
# 1426           1426        1426  199833   L. Unnerstall   27
# 11042         11042       11042  167437  D. Stroh-Engel   32
# 7785           7785        7785  236831       A. Seydel   22
# 14117         14117       14117  203835  D. Orlishausen   35
#
#                                                 Photo Nationality  \
# 1225   https://cdn.sofifa.org/players/4/19/200212.png     Germany
# 1426   https://cdn.sofifa.org/players/4/19/199833.png     Germany
# 11042  https://cdn.sofifa.org/players/4/19/167437.png     Germany
# 7785   https://cdn.sofifa.org/players/4/19/236831.png     Germany
# 14117  https://cdn.sofifa.org/players/4/19/203835.png     Germany
#
#                                       Flag  Overall  Potential  ... Composure  \
# 1225   https://cdn.sofifa.org/flags/21.png       76         76  ...      53.0
# ...

# %%
Germany.sort_values(by=['Weight'],ascending=False).head()
# Out:
#        Unnamed: 0.1  Unnamed: 0      ID           Name  Age  \
# 13520         13520       13520  239746   L. Watkowiak   22
# 1426           1426        1426  199833  L. Unnerstall   27
# 210             210         210  179783   R. FÃ¤hrmann   29
# 115             115         115  212190       N. SÃ¼le   22
# 165             165         165  213331         J. Tah   22
#
#                                                 Photo Nationality  \
# 13520  https://cdn.sofifa.org/players/4/19/239746.png     Germany
# 1426   https://cdn.sofifa.org/players/4/19/199833.png     Germany
# 210    https://cdn.sofifa.org/players/4/19/179783.png     Germany
# 115    https://cdn.sofifa.org/players/4/19/212190.png     Germany
# 165    https://cdn.sofifa.org/players/4/19/213331.png     Germany
#
#                                       Flag  Overall  Potential  ... Composure  \
# 13520  https://cdn.sofifa.org/flags/21.png       62         68  ...      21.0
# ...

# %%
Germany.sort_values(by=['Age'],ascending=False).head()
# Out:
#        Unnamed: 0.1  Unnamed: 0      ID          Name  Age  \
# 15133         15133       15133  104900     M. Gurski   39
# 8892           8892        8892  169243    A. Mintzel   36
# 5319           5319        5319   45473    C. Tiffert   36
# 12841         12841       12841  101317  M. Ratajczak   36
# 4045           4045        4045  167452       O. Fink   36
#
#                                                 Photo Nationality  \
# 15133  https://cdn.sofifa.org/players/4/19/104900.png     Germany
# 8892   https://cdn.sofifa.org/players/4/19/169243.png     Germany
# 5319    https://cdn.sofifa.org/players/4/19/45473.png     Germany
# 12841  https://cdn.sofifa.org/players/4/19/101317.png     Germany
# 4045   https://cdn.sofifa.org/players/4/19/167452.png     Germany
#
#                                       Flag  Overall  Potential  ... Composure  \
# 15133  https://cdn.sofifa.org/flags/21.png       60         60  ...      50.0
# ...

# %%
Germany[['Name','Wage']].sort_values(by=['Wage'],ascending=False).head()
# Out:
#               Name    Wage
# 11        T. Kroos  355000
# 18   M. ter Stegen  240000
# 55        L. SanÃ©  195000
# 74        M. Ãzil  190000
# 136  I. GÃ¼ndoÄan  175000

# %%
#shooting

# %%
player_shooting = fifa[['Name','ShotPower']]

# %%
player_shooting.sort_values(by=['ShotPower'],ascending=False).head()
# Out:
#                    Name  ShotPower
# 1     Cristiano Ronaldo       95.0
# 378                Hulk       94.0
# 1348         F. GuarÃ­n       93.0
# 890         L. Podolski       92.0
# 102               Naldo       92.0

# %%
#defending
player_defending= fifa[['Name','Marking']]

# %%
player_defending.sort_values(by=['Marking'],ascending=False).head()
# Out:
#              Name  Marking
# 152   A. Barzagli     94.0
# 24   G. Chiellini     93.0
# 77   M. Å kriniar     92.0
# 54         PiquÃ©     91.0
# 44   K. Koulibaly     91.0

# %%
real_madrid=fifa[fifa['Club']=='Real Madrid']

# %%
real_madrid.sort_values(by=['Wage'],ascending=False).head()
# Out:
#     Unnamed: 0.1  Unnamed: 0      ID          Name  Age  \
# 6              6           6  177003    L. ModriÄ   32
# 8              8           8  155862  Sergio Ramos   32
# 11            11          11  182521      T. Kroos   28
# 36            36          36  173731       G. Bale   28
# 30            30          30  197781          Isco   26
#
#                                              Photo Nationality  \
# 6   https://cdn.sofifa.org/players/4/19/177003.png     Croatia
# 8   https://cdn.sofifa.org/players/4/19/155862.png       Spain
# 11  https://cdn.sofifa.org/players/4/19/182521.png     Germany
# 36  https://cdn.sofifa.org/players/4/19/173731.png       Wales
# 30  https://cdn.sofifa.org/players/4/19/197781.png       Spain
#
#                                    Flag  Overall  Potential  ... Composure  \
# 6   https://cdn.sofifa.org/flags/10.png       91         91  ...      84.0
# 8   https://cdn.sofifa.org/flags/45.png       91         91  ...      82.0
# ...

# %%
real_madrid.sort_values(by=['ShotPower'],ascending=False).head()
# Out:
#      Unnamed: 0.1  Unnamed: 0      ID           Name  Age  \
# 36             36          36  173731        G. Bale   28
# 11             11          11  182521       T. Kroos   28
# 27             27          27  200145       Casemiro   26
# 79             79          79  220834  Marco Asensio   22
# 430           430         430  221639        Mariano   24
#
#                                               Photo         Nationality  \
# 36   https://cdn.sofifa.org/players/4/19/173731.png               Wales
# 11   https://cdn.sofifa.org/players/4/19/182521.png             Germany
# 27   https://cdn.sofifa.org/players/4/19/200145.png              Brazil
# 79   https://cdn.sofifa.org/players/4/19/220834.png               Spain
# 430  https://cdn.sofifa.org/players/4/19/221639.png  Dominican Republic
#
#                                      Flag  Overall  Potential  ... Composure  \
# 36    https://cdn.sofifa.org/flags/50.png       88         88  ...      86.0
# ...

# %%
from numpy import real
real_madrid.sort_values(by=['Marking'],ascending=False).head()
# Out:
#      Unnamed: 0.1  Unnamed: 0      ID          Name  Age  \
# 27             27          27  200145      Casemiro   26
# 62             62          62  201535     R. Varane   25
# 8               8           8  155862  Sergio Ramos   32
# 417           417         417  234035     Odriozola   22
# 123           123         123  204963      Carvajal   26
#
#                                               Photo Nationality  \
# 27   https://cdn.sofifa.org/players/4/19/200145.png      Brazil
# 62   https://cdn.sofifa.org/players/4/19/201535.png      France
# 8    https://cdn.sofifa.org/players/4/19/155862.png       Spain
# 417  https://cdn.sofifa.org/players/4/19/234035.png       Spain
# 123  https://cdn.sofifa.org/players/4/19/204963.png       Spain
#
#                                     Flag  Overall  Potential  ... Composure  \
# 27   https://cdn.sofifa.org/flags/54.png       88         90  ...      84.0
# 62   https://cdn.sofifa.org/flags/18.png       86         91  ...      82.0
# ...

# %%
real_madrid['Nationality'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 6                   Croatia
# 8                     Spain
# 11                  Germany
# 19                  Belgium
# 27                   Brazil
# 30                    Spain
# 35                   Brazil
# 36                    Wales
# 46               Costa Rica
# 62                   France
# 79                    Spain
# 105                  France
# 123                   Spain
# 172                   Spain
# 188                   Spain
# 328                   Spain
# 417                   Spain
# 430      Dominican Republic
# 573                   Spain
# 697                   Spain
# 754                   Spain
# 1143                 Brazil
# 2513                Uruguay
# 6724                  Spain
# 8732                  Spain
# 9141                  Spain
# 10178             Argentina
# 10269                 Spain
# 11163                 Spain
# 11327                 Spain
# 11877                 Spain
# ...
